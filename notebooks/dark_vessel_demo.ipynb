# %% [markdown]
# # TrajPrompt Dark-Vessel Demo
#
# Reproduces a public 2024 maritime sanctions case (e.g. STS transfers in the Black Sea) end-to-end:
#
# 1. Pull AIS daily dump from Danish Maritime Authority.
# 2. Run TGARD to identify candidate rendezvous.
# 3. Score candidates against the prompt with traj-CLIP.
# 4. Pull Sentinel-2 chips at the rendezvous coordinates.
# 5. Run SAM 2 to confirm vessels are visible.
# 6. Render the trajectory map.

# %%
from trajprompt.tgard import find_rendezvous
from trajprompt.traj_clip import TrajCLIPEncoder
from trajprompt.sam2_chip import Sam2ChipPipeline
